# %% [markdown]
# <a href="https://colab.research.google.com/github/suryaprakash01999/surya/blob/main/webscrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

i = requests.get("https://en.wikipedia.org/wiki/Rohit_Sharma")
j=i.content
doc= BeautifulSoup(j,"lxml")
doc
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Rohit Sharma - Wikipedia</title>
# ...

# %%
table = doc.find_all("table")
ta = table[0]
ta
# Out:
# <table class="infobox vcard" style="width: 25em"><caption class="infobox-title fn" style="font-size: 125%"><div class="fn" style="display: inline;">Rohit Sharma</div></caption><tbody><tr><td class="infobox-image" colspan="2"><a class="image" href="/wiki/File:Rohit_Sharma_during_the_India_vs_Australia_4th_Test_match_at_Narendra_Modi_Stadium.jpg"><img alt="Rohit Sharma during the India vs Australia 4th Test match at Narendra Modi Stadium.jpg" data-file-height="1002" data-file-width="836" decoding="async" height="264" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1d/Rohit_Sharma_during_the_India_vs_Australia_4th_Test_match_at_Narendra_Modi_Stadium.jpg/220px-Rohit_Sharma_during_the_India_vs_Australia_4th_Test_match_at_Narendra_Modi_Stadium.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1d/Rohit_Sharma_during_the_India_vs_Australia_4th_Test_match_at_Narendra_Modi_Stadium.jpg/330px-Rohit_Sharma_during_the_India_vs_Australia_4th_Test_match_at_Narendra_Modi_Stadium.jpg
# ...

# %%
df1.shape
# Out:
# (52, 5)

# %%
from pandas.io.formats.style_render import DataFrame
df = pd.read_html(str(ta))
df1 = pd.DataFrame(df[0])
df1
# Out:
#                                                     0  \
# 0                                       Rohit in 2023
# 1                                Personal information
# 2                                           Full name
# 3                                                Born
# 4                                            Nickname
# 5                                              Height
# 6                                             Batting
# 7                                             Bowling
# 8                                                Role
# 9                           International information
# 10                                      National side
# 11                               Test debut (cap 280)
# 12                                          Last Test
# 13                                ODI debut (cap 168)
# 14                                           Last ODI
# 15                                      ODI shirt no.
# ...

# %%
df1.to_csv('rohit')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       51 non-null     object
#  1   1       51 non-null     object
#  2   2       18 non-null     object
#  3   3       13 non-null     object
#  4   4       13 non-null     object
# dtypes: object(5)
# memory usage: 2.2+ KB

# %%
df1.describe()
# Out:
#                 0   1   2   3   4
# count          51  51  18  13  13
# unique         48  49  17  12  12
# top     Runner-up   0   0   0   0
# freq            3   2   2   2   2
